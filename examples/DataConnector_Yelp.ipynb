# %% [markdown]
# # Connector for Yelp
#
# In this example, we will be going over how to use Connector with Yelp.

# %% [markdown]
# ## Preprocessing
#
# connector is a component in the dataprep library that aims to simplify the data access by providing a standard API set. The goal is to help the users skip the complex API configuration. In this tutorial, we demonstrate how to use connector library with Yelp.
#
# If you haven't installed dataprep, run command `pip install dataprep` or execute the following cell.

# %%
># Run me if you'd like to install
>!pip install dataprep

# %% [markdown]
# # Obtaining access token from Yelp
#
# To connect to Yelp, you need to generate a token. This token is a unique identifier of an application requesting access to the Yelp's API. Once an application creates the token, it will act as your credential when making an API request.
#
# To receive an access token, the user needs to create a server-side application from Yelp. You can get a token by following the [Yelp document](https://www.yelp.com/developers/documentation/v3/authentication).
# Simply create an application and generate a key.

# %% [markdown]
# Store the token or API Key in a secure location as it will be used to provide you access to the Yelp's restaurant data.

# %% [markdown]
# # Download and store the configuration files in dataprep.
#
# The configuration files are used to configure the parameters and initial setup for the API. The available configuration files can be manually downloaded here: [Configuration Files](https://github.com/sfu-db/DataConnectorConfigs) or automatically downloaded at usage.
#
# Store the configuration file in the dataprep folder.

# %% [markdown]
# # Initialize connector
#
# To initialize run the following code. Copy and paste the Yelp API key into the **access_token** variable and ensure the connector path is correct. Once you have that running you can use the built in functions available in connector.

# %%
from dataprep.connector import Connector

access_token = '<API Token>'
dc = Connector("yelp", _auth={"access_token":access_token})

# %% [markdown]
# # Functionalities
#
# Connector has several functions you can perform to gain insight on the data downloaded from Yelp.

# %% [markdown]
# ### Connector.info
# The info method gives information and guidelines of using the connector. There are 3 sections in the response and they are table, parameters and examples.
# >1. Table - The table(s) being accessed.
# >2. Parameters - Identifies which parameters can be used to call the method.
# **Note:** Either **term** (Yelp specification) or **_q** (our unified paramater) can be used to fetch records that match the search pattern.
# >3. Examples - Shows how you can call the methods in the Connector class.

# %%
dc.info()
# Out:
# Table yelp.businesses
#
# Parameters
# ----------
# location required
# term, latitude, longitude, limit optional
#
# Examples
# --------
# >>> dc.query("businesses", location="word1")
# >>> dc.show_schema("businesses")

# %% [markdown]
# ### Connector.show_schema
# The show_schema method returns the schema of the website data to be returned in a Dataframe. There are two columns in the response. The first column is the column name and the second is the datatype.
#
# As an example, lets see what is in the business table.

# %%
dc.show_schema("businesses")
# Out:
# table: businesses
#    column_name data_type
# 0       rating     float
# 1        price    string
# 2        phone    string
# 3         name    string
# 4          url    string
# 5     latitude     float
# 6   longtitude     float
# 7         city    string
# 8      country    string
# 9     address2    string
# 10    address3    string
# 11       state    string
# 12    address1    string
# 13    zip_code    string

# %% [markdown]
# ### Connector.query
# The query method downloads the website data and displays it in a Dataframe. The parameters must meet the requirements as indicated in connector.info for the operation to run.
#
# When the data is received from the server, it will either be in a JSON or XML format. The connector reformats the data in pandas Dataframe for the convenience of downstream operations.
#
# As an example, let's try to get the data from the "business" table, providing the term "city" and location "seattle".

# %%
df = await dc.query("businesses", _q="city", location="seattle")
df
# Out:
#     rating price         phone                                    name  \
# 0      3.5  None  +12066842489                         City of Seattle
# 1      3.5     $  +12063231715                             City Market
# 2      4.0    $$  +12066829329                               City Fish
# 3      3.0   $$$  +12064413663                              City Foods
# 4      5.0  None  +12066824424                       City Chiropractic
# 5      4.5    $$  +12063240737              City People's Garden Store
# 6      3.0    $$  +12064943250                                  Target
# 7      3.0  None  +14257756477               City of Mountlake Terrace
# 8      4.5  None                                      City of Bellevue
# 9      4.0    $$  +12066212228                  Harbor City Restaurant
# 10     3.5  None  +12064480509                               Churchome
# 11     4.5    $$  +12064864743                          Windy City Pie
# 12     4.0  None  +12069052100                            Space Needle
# 13     2.5  None                                      City of Lynnwood
# 14     3.5  None  +14258033233                               Churchome
# 15     3.5  None  +14257325300                    City Center Bellevue
# 16     5.0  None  +13603224511  Law Offices of D Merrit and Associates
# 17     5.0    $$  +12065695068                  Jet City Device Repair
# 18     4.5  None                                       City of Bothell
# 19     4.5  None  +12063053910                            The Fry Guys
#
#                                                   url   latitude  longtitude  \
# 0   https://www.yelp.com/biz/city-of-seattle-seatt...  47.602820 -122.329260
# 1   https://www.yelp.com/biz/city-market-seattle?a...  47.617043 -122.326439
# 2   https://www.yelp.com/biz/city-fish-seattle-2?a...  47.608754 -122.340636
# 3   https://www.yelp.com/biz/city-foods-seattle?ad...  47.617890 -122.345820
# 4   https://www.yelp.com/biz/city-chiropractic-sea...  47.612790 -122.336560
# 5   https://www.yelp.com/biz/city-peoples-garden-s...  47.624580 -122.294240
# 6   https://www.yelp.com/biz/target-seattle-7?adju...  47.608941 -122.339058
# 7   https://www.yelp.com/biz/city-of-mountlake-ter...  47.787910 -122.312750
# 8   https://www.yelp.com/biz/city-of-bellevue-bell...  47.615850 -122.196880
# 9   https://www.yelp.com/biz/harbor-city-restauran...  47.598210 -122.323390
# 10  https://www.yelp.com/biz/churchome-seattle?adj...  47.616320 -122.351000
# 11  https://www.yelp.com/biz/windy-city-pie-seattl...  47.672348 -122.354060
# 12  https://www.yelp.com/biz/space-needle-seattle?...  47.620490 -122.349230
# 13  https://www.yelp.com/biz/city-of-lynnwood-lynn...  47.826014 -122.293353
# 14  https://www.yelp.com/biz/churchome-kirkland?ad...  47.683784 -122.166012
# 15  https://www.yelp.com/biz/city-center-bellevue-...  47.615010 -122.195890
# 16  https://www.yelp.com/biz/law-offices-of-d-merr...  47.578411 -122.149242
# 17  https://www.yelp.com/biz/jet-city-device-repai...  47.651694 -122.336104
# 18  https://www.yelp.com/biz/city-of-bothell-bothe...  47.762009 -122.203178
# 19  https://www.yelp.com/biz/the-fry-guys-seattle?...  47.587070 -122.333740
#
#                  city country  address2 address3 state  \
# 0             Seattle      US                       WA
# 1             Seattle      US                       WA
# 2             Seattle      US                       WA
# 3             Seattle      US                       WA
# 4             Seattle      US  Ste 1645             WA
# 5             Seattle      US                       WA
# 6             Seattle      US                       WA
# 7   Mountlake Terrace      US      None     None    WA
# 8            Bellevue      US                       WA
# 9             Seattle      US                       WA
# 10            Seattle      US                       WA
# 11            Seattle      US      None             WA
# 12            Seattle      US                       WA
# 13           Lynnwood      US      None     None    WA
# 14           Kirkland      US                       WA
# 15           Bellevue      US                       WA
# 16           Bellevue      US   Ste 100             WA
# 17            Seattle      US      None             WA
# 18            Bothell      US                       WA
# 19            Seattle      US      None             WA
#
#                   address1 zip_code
# 0                             98104
# 1        1722 Bellevue Ave    98122
# 2             1535 Pike Pl    98101
# 3             2522 5th Ave    98121
# 4            509 Olive Way    98101
# 5        2939 E Madison St    98112
# 6             1401 2nd Ave    98101
# 7         5906 232nd St SW    98043
# 8                             98004
# 9            707 S King St    98104
# 10            2700 1st Ave    98121
# 11      5918 Phinney Ave N    98103
# 12            400 Broad St    98109
# 13                    None    98036
# 14       9051 132nd Ave NE    98033
# 15        500 108th Ave NE    98004
# 16        14205 SE 36th St    98006
# 17  3642 Wallingford Ave N    98103
# 18                            98011
# 19          1740 1st Ave S    98134

# %% [markdown]
# From query results, you can see how easy it is to download the restaurant data from Yelp into a pandas Dataframe.
#
# Now that you have an understanding of how connector operates, you can easily accomplish the task with two lines of code.
#
# >1. dc = Connector(...)
# >2. dc.query(...)

# %% [markdown]
# # That's all for now.
# If you are interested in writing your own configuration file or modify an existing one, refer to the [Configuration Files](https://github.com/sfu-db/DataConnectorConfigs>).
