# %% [markdown]
# # Connector for Twitter
#
# In this example, we will be going over how to use Connector with Twitter.

# %% [markdown]
# ## Prerequisites
#
# connector is a component in the dataprep library that aims to simplify the data access by providing a standard API set. The goal is to help the users skip the complex API configuration. In this tutorial, we demonstrate how to use connector library with Twitter.
#
# If you haven't installed dataprep, run command `pip install dataprep` or execute the following cell.

# %%
# Run me if you'd like to install
#!pip install dataprep

# %% [markdown]
# # Obtaining access token from Twitter
#
# In order for you to get the Twitter feed working, you need four keys - the **Consumer Key**, **Consumer Secret**, **Access Token** and **Access Token Secret**. These keys are unique identifiers of an application requesting access to the Twitter's API. Once an application creates the token, it will act as your credential when making an API request. These keys and tokens can be obtained with the following three simple steps.
#
# ##### 1. Create a Developer Account
# In order to access the data, you will need to create a server-side application on Twitter and to do so, you will need to create a developer account in order to create an application. You can sign up for the developer account on the [Twitter Developer Account](https://developer.twitter.com/en) by following the prompts. An email confirming your approval to the developer account will be sent to you shortly after the sign up.
#
# ##### 2. Create an Application
# Logging in to your developer account once you gain access, create an app in the [Apps section of your profile](https://developer.twitter.com/en/apps). While creating an application, fill in the name, description and URL of your website. You can leave the clalback URL and other URL sections if needed.
#
# ##### 3. Generate Auth Keys and tokens
#
# After you successfully create an application, you can find your access keys and token Keys in the **Keys and Tokens** section of your Application Details. Generate the Access token and Access Token Secret and store them in a secure location as it will be used to provide you access to the Twitter's data.

# %% [markdown]
# # Initialize connector
#
# To initialize run the following code. Copy and paste the **Twitter Access Token Secret** into the **access_token** variable and ensure the connector path is correct. This returns an object establishing a connection with Twitter. Once you have that running you can use the built in functions available in connector.

# %%
from dataprep.connector import Connector

client_id = '<Consumer API Key>'
client_secret = '<Consumer API Secret Key>'
dc = Connector("twitter", _auth={"client_id":client_id, "client_secret":client_secret})
dc

# %% [markdown]
# # Functionalities
#
# Connector has several functions you can perform to gain insight on the data downloaded from twitter.

# %% [markdown]
# ### Connector.info
# The info method gives information and guidelines of using the connector. There are 3 sections in the response and they are table, parameters and examples.
# >1. Table - The table(s) being accessed.
# >2. Parameters - Identifies which parameters can be used to call the method. For Twitter, q is a required parameter that acts as a filter.
# >3. Examples - Shows how you can call the methods in the Connector class.

# %%
dc.info()
# Out:
# Table twitter.tweets
#
# Parameters
# ----------
# q required
# count, max_id optional
#
# Examples
# --------
# >>> dc.query("tweets", q="word1")
# >>> dc.show_schema("tweets")

# %% [markdown]
# ### Connector.show_schema
# The show_schema method returns the schema of the website data to be returned in a Dataframe. There are two columns in the response. The first column is the column name and the second is the datatype.
#
# As an example, lets see what is in the tweets table.

# %%
dc.show_schema("tweets")
# Out:
# table: tweets
#          column_name data_type
# 0         created_at    string
# 1               text    string
# 2          truncated   boolean
# 3  iso_language_code    string
# 4           hashtags    string

# %% [markdown]
# ### Connector.query
# The query method downloads the website data and displays it in a Dataframe. The parameters must meet the requirements as indicated in connector.info for the operation to run. You can use the **count** parameter to specify the number of tweets to be fetched. Each request can currently fetch a maximum of 100 requests.
#
# When the data is received from the server, it will either be in a JSON or XML format. The connector reformats the data in pandas Dataframe for the convenience of downstream operations.
#
# As an example, let's try to get 50 tweets related to covid-19 from the Twitter Website.

# %% [markdown]
# #### Searching for tweets related to COVID-19

# %%
df = dc.query("tweets", q="covid-19", count=50)
df
# Out:
#                         created_at  \
# 0   Sat Jun 13 06:19:59 +0000 2020
# 1   Sat Jun 13 06:19:59 +0000 2020
# 2   Sat Jun 13 06:19:59 +0000 2020
# 3   Sat Jun 13 06:19:59 +0000 2020
# 4   Sat Jun 13 06:19:59 +0000 2020
# 5   Sat Jun 13 06:19:59 +0000 2020
# 6   Sat Jun 13 06:19:59 +0000 2020
# 7   Sat Jun 13 06:19:59 +0000 2020
# 8   Sat Jun 13 06:19:59 +0000 2020
# 9   Sat Jun 13 06:19:59 +0000 2020
# 10  Sat Jun 13 06:19:59 +0000 2020
# 11  Sat Jun 13 06:19:59 +0000 2020
# 12  Sat Jun 13 06:19:59 +0000 2020
# 13  Sat Jun 13 06:19:59 +0000 2020
# 14  Sat Jun 13 06:19:58 +0000 2020
# 15  Sat Jun 13 06:19:58 +0000 2020
# 16  Sat Jun 13 06:19:58 +0000 2020
# 17  Sat Jun 13 06:19:58 +0000 2020
# 18  Sat Jun 13 06:19:58 +0000 2020
# 19  Sat Jun 13 06:19:58 +0000 2020
# 20  Sat Jun 13 06:19:58 +0000 2020
# 21  Sat Jun 13 06:19:57 +0000 2020
# 22  Sat Jun 13 06:19:57 +0000 2020
# 23  Sat Jun 13 06:19:57 +0000 2020
# 24  Sat Jun 13 06:19:57 +0000 2020
# 25  Sat Jun 13 06:19:57 +0000 2020
# 26  Sat Jun 13 06:19:57 +0000 2020
# 27  Sat Jun 13 06:19:57 +0000 2020
# 28  Sat Jun 13 06:19:57 +0000 2020
# 29  Sat Jun 13 06:19:57 +0000 2020
# 30  Sat Jun 13 06:19:57 +0000 2020
# 31  Sat Jun 13 06:19:57 +0000 2020
# 32  Sat Jun 13 06:19:57 +0000 2020
# 33  Sat Jun 13 06:19:57 +0000 2020
# 34  Sat Jun 13 06:19:56 +0000 2020
# 35  Sat Jun 13 06:19:56 +0000 2020
# 36  Sat Jun 13 06:19:56 +0000 2020
# 37  Sat Jun 13 06:19:56 +0000 2020
# 38  Sat Jun 13 06:19:56 +0000 2020
# 39  Sat Jun 13 06:19:56 +0000 2020
# 40  Sat Jun 13 06:19:56 +0000 2020
# 41  Sat Jun 13 06:19:56 +0000 2020
# 42  Sat Jun 13 06:19:56 +0000 2020
# 43  Sat Jun 13 06:19:56 +0000 2020
# 44  Sat Jun 13 06:19:56 +0000 2020
# 45  Sat Jun 13 06:19:56 +0000 2020
# 46  Sat Jun 13 06:19:56 +0000 2020
# 47  Sat Jun 13 06:19:56 +0000 2020
# 48  Sat Jun 13 06:19:55 +0000 2020
# 49  Sat Jun 13 06:19:55 +0000 2020
#
#                                                  text  truncated  \
# 0   RT @dhruv_rathee: It’s cheaper to stay 1 night...      False
# 1   RT @el_nonymous: Ayah Dea meninggal karena COV...      False
# 2   RT @som3thingwicked: @SharylAttkisson Well, Co...      False
# 3   RT @JuansRodriguez1: Cuidarse del COVID-19 en ...      False
# 4   RT @edanbrou: @subtanyarl Yang lucu di daerahk...      False
# 5   RT @NPR: Alabama is one of several states stra...      False
# 6   RT @boohyang19: Specimen: sputum from a Covid-...      False
# 7   @NigarNawab @TheTweetOfGod And also COVID 19 c...      False
# 8   RT @teanval0207: Ciper: Minsal informó a la OM...      False
# 9   RT @MaddowBlog: "Florida’s former top coronavi...      False
# 10  RT @NPR: Alabama is one of several states stra...      False
# 11  RT @rajaapiterbuang: @subtanyarl Dan mirisnya ...      False
# 12  The new interactive map shows where Covid-19 v...      False
# 13  RT @Apvandergeest: Hier spuit 11 weer. ‘Wees v...      False
# 14  RT @batacatlove1: So let me get this straight,...      False
# 15  RT @redcrab_library: やっぱり新型コロナやコロナの名称控えた方がいいんじ...      False
# 16  RT @oldiesclub: Meet Artos &lt;3 Artos is a 10...      False
# 17  RT @sakshijoshii: गुजरात में कोरोना का क़हर, श...      False
# 18  RT @axmz_: YEMEN CRISIS - A THREAD\nITS IMPORT...      False
# 19  RT @MJhogasundram: How Refugee Doctors Are Hel...      False
# 20  RT @el_nonymous: Ayah Dea meninggal karena COV...      False
# 21  RT @TIME: As COVID-19 lockdowns end, people ar...      False
# 22  RT @diorslxt: SAY HIS FUCKING NAME. Robert Ful...      False
# 23  indo dormi pra sonha com ela \n\nvacina pra co...      False
# 24  RT @GeorgeTakei: So...if Covid-19 is a Democra...      False
# 25  RT @Foro_TV: OMS pide a México dar ‘mensajes c...      False
# 26  RT @IiyamaAkari: 自分の気に入らない考えや政策にファシズムというレッテルを貼...      False
# 27  RT @NPR: Alabama is one of several states stra...      False
# 28  RT @IiyamaAkari: 自分の気に入らない考えや政策にファシズムというレッテルを貼...      False
# 29  Stay-home orders likely slowed COVID-19 spread...      False
# 30  RT @JeffryOqueli: Guatemala y su tasa de letal...      False
# 31  ଦିଲ୍ଲୀ ପୁଲିସକୁ ମିଳିଲା ଡିସଇନଫେକ୍ଟ ମେସିନ୍ : ଆଉ ଧ...       True
# 32  Stay-home orders likely slowed COVID-19 spread...      False
# 33  RT @Claudiashein: Mensaje importante sobre el ...      False
# 34  RT @kiddikicks: Kiddikicks is temporarily clos...      False
# 35  Stay-home orders likely slowed COVID-19 spread...      False
# 36  RT @slmandel: NEWS: The University of Houston ...      False
# 37  RT @Outbreaks101: #NewZealand contained its CO...      False
# 38  RT @techreview: Why simply waiting for herd im...      False
# 39  RT @brandinsideasia: YenlyYours มะม่วงปั่นแบรน...      False
# 40  RT @iampankaj_kumar: समय है एक होने का न मतभेद...      False
# 41  RT @el_nonymous: Ayah Dea meninggal karena COV...      False
# 42  RT @SwimmingWorld: - https://t.co/jNnQymPyET -...      False
# 43  RT @Bijzonderheid: Staat plots dat HEPA-filter...      False
# 44  RT @luscas: indo dormi pra sonha com ela \n\nv...      False
# 45  RT @axmz_: YEMEN CRISIS - A THREAD\nITS IMPORT...      False
# 46  RT @JoshiPralhad: Chaired a meeting to review ...      False
# 47  RT @asumsico: Kapolri Jenderal Idham Azis mene...      False
# 48  RT @fire_scot: Many businesses have taken step...      False
# 49  RT @RawStory: Florida stuck with nearly a mill...      False
#
#    iso_language_code                                           hashtags
# 0                 en                                                 []
# 1                 in                                                 []
# 2                 en                                                 []
# 3                 es                                                 []
# 4                 in                                                 []
# 5                 en                                                 []
# 6                 en                                                 []
# 7                 en                                                 []
# 8                 es                                                 []
# 9                 en                                                 []
# 10                en                                                 []
# 11                in                                                 []
# 12                en                                                 []
# 13                nl                                                 []
# 14                en                                                 []
# 15                ja                                                 []
# 16                en                                                 []
# 17                hi                                                 []
# 18                en                                                 []
# 19                en                                                 []
# 20                in                                                 []
# 21                en                                                 []
# 22                en                                                 []
# 23                pt                                                 []
# 24                en                                                 []
# 25                es                                                 []
# 26                ja                                                 []
# 27                en                                                 []
# 28                ja                                                 []
# 29                en                                                 []
# 30                es                                                 []
# 31                or                                                 []
# 32                en                                                 []
# 33                es  [{'text': 'ProtégeteYProtegeALosDemás', 'indic...
# 34                en                                                 []
# 35                en                                                 []
# 36                en                                                 []
# 37                en  [{'text': 'NewZealand', 'indices': [18, 29]}, ...
# 38                en                                                 []
# 39                th                                                 []
# 40                hi                                                 []
# 41                in                                                 []
# 42                en                                                 []
# 43                nl                                                 []
# 44                pt                                                 []
# 45                en                                                 []
# 46                en  [{'text': 'Covid_19', 'indices': [86, 95]}, {'...
# 47                in                                                 []
# 48                en                                                 []
# 49                en                                                 []

# %% [markdown]
# # That's all for now.
# If you are interested in writing your own configuration file or modify an existing one, refer to the [Configuration Files](https://github.com/sfu-db/DataConnectorConfigs>).
