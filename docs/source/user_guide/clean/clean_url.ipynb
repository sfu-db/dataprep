# %% [markdown]
# # `clean_url()`: Clean and validate urls

# %% [markdown]
# ## Introduction
#
# The function `clean_url()` cleans a column containing urls, and extracts the important parameters including cleaned path, queries, scheme,etc. The function `validate_url()` validates either a single url or a column of urls, returning True if the value is valid, and False otherwise.
#
# `clean_url()` function extracts all the important features of the url and creates an additional column containing key value pairs of the parameters, following are the features it extracts:
#
# * scheme (string)
# * host (string)
# * cleaned path (string)
# * queries (key-value pairs)
#
# Remove Auth tokens: Sometimes we would like to remove certain sensitive information which is usually contained in a url for e.g. access_tokens, user information, etc. `clean_url()` provides us with an option to remove this information with `remove_auth` parameter. The usage of all parameters is explained in depth in the sections below.
#
# Invalid parsing is handled with the `errors` parameter:
#
# * "coerce" (default), then invalid parsing will be set as NaN
# * "ignore", then invalid parsing will return the input
# * "raise", then invalid parsing will raise an exception
#
# After cleaning, a **report** is printed that provides the following information:
#
# * How many values were cleaned (the value must be transformed)
# * How many values could not be parsed
# * If `remove_auth` is specified, then displays how many queries were removed from how many rows
# * And the data summary: how many values are in the correct format, and how many values are null
#
# The following sections demonstrate the functionality of `clean_url()` and `validate_url()`.

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({"messy_url":
                   ["random text which is not a url",
                    "http://www.facebookee.com/otherpath?auth=facebookeeauth&token=iwusdkc&not_token=hiThere&another_token=12323423",
                    "https://www.sfu.ca/ficticiouspath?auth=sampletoken1&studentid=1234&loc=van", 
                    "notaurl", 
                    np.nan,
                    None, 
                    "https://www.sfu.ca/ficticiouspath?auth=sampletoken2&studentid=1230&loc=bur", 
                    "", 
                    {"not_a_url" : True}, 
                    "2345678", 
                    345345345,
                    "https://www.sfu.ca/ficticiouspath?auth=sampletoken3&studentid=1231&loc=sur",
                    "https://www.sfu.ca/ficticiouspath?auth=sampletoken1&studentid=1232&loc=van",
                    ]
                  })
df
# Out:
#                                             messy_url
# 0                      random text which is not a url
# 1   http://www.facebookee.com/otherpath?auth=faceb...
# 2   https://www.sfu.ca/ficticiouspath?auth=samplet...
# 3                                             notaurl
# 4                                                 NaN
# 5                                                None
# 6   https://www.sfu.ca/ficticiouspath?auth=samplet...
# 7
# 8                                 {'not_a_url': True}
# 9                                             2345678
# 10                                          345345345
# 11  https://www.sfu.ca/ficticiouspath?auth=samplet...
# 12  https://www.sfu.ca/ficticiouspath?auth=samplet...

# %% [markdown]
# ## 1. default: `clean_url()`
# By default, all the parameters are set to default, `inplace = False`, `split = False`, `remove_auth = False`, `report = True`,`errors = coerce`.

# %%
from dataprep.clean import clean_url
df_default = clean_url(df, column="messy_url")
df_default
# Out:
# Url Cleaning report:
#         5 values parsed (38.46 %)
#         8 values unable to be parsed (61.54 %), set to NaN
# Result contains parsed key-value pairs for 5 (38.46 %) rows (stored in column `messy_url_details`) and 8 null values(61.54 %).
#                                             messy_url  \
# 0                      random text which is not a url
# 1   http://www.facebookee.com/otherpath?auth=faceb...
# 2   https://www.sfu.ca/ficticiouspath?auth=samplet...
# 3                                             notaurl
# 4                                                 NaN
# 5                                                None
# 6   https://www.sfu.ca/ficticiouspath?auth=samplet...
# 7
# 8                                 {'not_a_url': True}
# 9                                             2345678
# 10                                          345345345
# 11  https://www.sfu.ca/ficticiouspath?auth=samplet...
# 12  https://www.sfu.ca/ficticiouspath?auth=samplet...
#
#                                     messy_url_details
# 0                                                 NaN
# 1   {'scheme': 'http', 'host': 'www.facebookee.com...
# 2   {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 12  {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...

# %% [markdown]
# We can see that in the new dataframe `df_default` a new column is created `messy_url_details`, this follows the naming convention of `orginal_column_name`**_details** (`messy_url_details` in our case).
#
# Now let us see what one of the cells in `messy_url_details` looks like.

# %%
df_default["messy_url_details"][1]
# Out:
# {'scheme': 'http',
#  'host': 'www.facebookee.com',
#  'messy_url_clean': 'http://www.facebookee.com/otherpath',
#  'queries': {'auth': 'facebookeeauth',
#   'token': 'iwusdkc',
#   'not_token': 'hiThere',
#   'another_token': '12323423'}}

# %% [markdown]
# ## 2. `remove_auth` parameter
#
# Sometimes we need to remove sensitive information when parsing a url, we can do this in the clean_url() function by specifying the `remove_auth` parameter to be True or we can can specify a list of parameters to removed. Hence `remove_auth` can be a `boolean` value or list of strings.
#
# When `remove_auth` is set to the boolean value of `True`, clean_url() looks for auth tokens based on the default list of token names (provided below) and removes them. When `remove_auth` is set to list of strings it creates a union of the user provided list and default list to create a new set of token words to be removed.
#
# `default_list = {
#     "access_token",
#     "auth_key",
#     "auth",
#     "password",
#     "username",
#     "login",
#     "token",
#     "passcode",
#     "access-token",
#     "auth-key",
#     "authentication",
#     "authentication-key",
# }
# `
#
# Lets have a look at the same dataframe and the two scenerios described above (by looking at the second row).

# %% [markdown]
# ### a. `remove_auth = True` (boolean)

# %%
df_remove_auth_boolean = clean_url(df, column="messy_url", remove_auth=True)
df_remove_auth_boolean["messy_url_details"][1]
# Out:
# Url Cleaning report:
#         5 values parsed (38.46 %)
#         8 values unable to be parsed (61.54 %), set to NaN
# Removed 6 auth queries from 5 rows
# Result contains parsed key-value pairs for 5 (38.46 %) rows (stored in column `messy_url_details`) and 8 null values(61.54 %).
# {'scheme': 'http',
#  'host': 'www.facebookee.com',
#  'messy_url_clean': 'http://www.facebookee.com/otherpath',
#  'queries': {'not_token': 'hiThere', 'another_token': '12323423'}}

# %% [markdown]
# As we can see queries `auth` & `token` were removed from the result but `not_token` and `another_token` were included, this is because `auth` and `token` were specified in `default_list`. Also notice the **additional line** giving the stats on how many queries were removed from how many rows.

# %% [markdown]
# ### b. remove_auth = list of string

# %%
df_remove_auth_list = clean_url(df, column="messy_url", remove_auth=["another_token"])
df_remove_auth_list["messy_url_details"][1]
# Out:
# Url Cleaning report:
#         5 values parsed (38.46 %)
#         8 values unable to be parsed (61.54 %), set to NaN
# Removed 7 auth queries from 5 rows
# Result contains parsed key-value pairs for 5 (38.46 %) rows (stored in column `messy_url_details`) and 8 null values(61.54 %).
# {'scheme': 'http',
#  'host': 'www.facebookee.com',
#  'messy_url_clean': 'http://www.facebookee.com/otherpath',
#  'queries': {'not_token': 'hiThere'}}

# %% [markdown]
# As we can see queries `auth`, `token` and `another_token` were removed but `not_token` was included in the result, this is because a new list was created by creating a union of `default_list` and user defined list and queries were removed based on the new combined list

# %% [markdown]
# ## 3. `split` Parameter
# The `split` parameter adds individual columns containing the containing all the extracted features to the given DataFrame.

# %%
df_remove_split = clean_url(df, column="messy_url", split=True)
df_remove_split
# Out:
# Url Cleaning report:
#         5 values parsed (38.46 %)
#         8 values unable to be parsed (61.54 %), set to NaN
# Result contains parsed values for 5(38.46 %) rows and 8 null values(61.54 %).
#                                             messy_url scheme  \
# 0                      random text which is not a url    NaN
# 1   http://www.facebookee.com/otherpath?auth=faceb...   http
# 2   https://www.sfu.ca/ficticiouspath?auth=samplet...  https
# 3                                             notaurl    NaN
# 4                                                 NaN    NaN
# 5                                                None    NaN
# 6   https://www.sfu.ca/ficticiouspath?auth=samplet...  https
# 7                                                        NaN
# 8                                 {'not_a_url': True}    NaN
# 9                                             2345678    NaN
# 10                                          345345345    NaN
# 11  https://www.sfu.ca/ficticiouspath?auth=samplet...  https
# 12  https://www.sfu.ca/ficticiouspath?auth=samplet...  https
#
#                   host                      messy_url_clean  \
# 0                  NaN                                  NaN
# 1   www.facebookee.com  http://www.facebookee.com/otherpath
# 2           www.sfu.ca    https://www.sfu.ca/ficticiouspath
# 3                  NaN                                  NaN
# 4                  NaN                                  NaN
# 5                  NaN                                  NaN
# 6           www.sfu.ca    https://www.sfu.ca/ficticiouspath
# 7                  NaN                                  NaN
# 8                  NaN                                  NaN
# 9                  NaN                                  NaN
# 10                 NaN                                  NaN
# 11          www.sfu.ca    https://www.sfu.ca/ficticiouspath
# 12          www.sfu.ca    https://www.sfu.ca/ficticiouspath
#
#                                               queries
# 0                                                 NaN
# 1   {'auth': 'facebookeeauth', 'token': 'iwusdkc',...
# 2   {'auth': 'sampletoken1', 'studentid': '1234', ...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'auth': 'sampletoken2', 'studentid': '1230', ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'auth': 'sampletoken3', 'studentid': '1231', ...
# 12  {'auth': 'sampletoken1', 'studentid': '1232', ...

# %% [markdown]
# ## 4. `inplace` parameter
# Replaces the original column with `orginal_column_name`_details.

# %%
df_remove_inplace = clean_url(df, column="messy_url", inplace=True)
df_remove_inplace
# Out:
# Url Cleaning report:
#         5 values parsed (38.46 %)
#         8 values unable to be parsed (61.54 %), set to NaN
# Result contains parsed key-value pairs for 5 (38.46 %) rows (stored in column `messy_url_details`) and 8 null values(61.54 %).
#                                     messy_url_details
# 0                                                 NaN
# 1   {'scheme': 'http', 'host': 'www.facebookee.com...
# 2   {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 12  {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...

# %% [markdown]
# ## 5. `split` and `inplace`
# Replaces the original column with other columns based on the split parameters.

# %%
df_remove_inplace_split = clean_url(df, column="messy_url", inplace=True, split=True)
df_remove_inplace_split
# Out:
# Url Cleaning report:
#         5 values parsed (38.46 %)
#         8 values unable to be parsed (61.54 %), set to NaN
# Result contains parsed values for 5(38.46 %) rows and 8 null values(61.54 %).
#    scheme                host                      messy_url_clean  \
# 0     NaN                 NaN                                  NaN
# 1    http  www.facebookee.com  http://www.facebookee.com/otherpath
# 2   https          www.sfu.ca    https://www.sfu.ca/ficticiouspath
# 3     NaN                 NaN                                  NaN
# 4     NaN                 NaN                                  NaN
# 5     NaN                 NaN                                  NaN
# 6   https          www.sfu.ca    https://www.sfu.ca/ficticiouspath
# 7     NaN                 NaN                                  NaN
# 8     NaN                 NaN                                  NaN
# 9     NaN                 NaN                                  NaN
# 10    NaN                 NaN                                  NaN
# 11  https          www.sfu.ca    https://www.sfu.ca/ficticiouspath
# 12  https          www.sfu.ca    https://www.sfu.ca/ficticiouspath
#
#                                               queries
# 0                                                 NaN
# 1   {'auth': 'facebookeeauth', 'token': 'iwusdkc',...
# 2   {'auth': 'sampletoken1', 'studentid': '1234', ...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'auth': 'sampletoken2', 'studentid': '1230', ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'auth': 'sampletoken3', 'studentid': '1231', ...
# 12  {'auth': 'sampletoken1', 'studentid': '1232', ...

# %% [markdown]
# ## 6. `errors` parameter
# * "coerce" (default), then invalid parsing will be set as NaN
# * "ignore", then invalid parsing will return the input
# * "raise", then invalid parsing will raise an exception

# %% [markdown]
# ### a. "coerce" (default)
# This is the default value of the parameters, this sets the invalid parsing to NaN.

# %%
df_remove_errors_default = clean_url(df, column="messy_url")
df_remove_errors_default
# Out:
# Url Cleaning report:
#         5 values parsed (38.46 %)
#         8 values unable to be parsed (61.54 %), set to NaN
# Result contains parsed key-value pairs for 5 (38.46 %) rows (stored in column `messy_url_details`) and 8 null values(61.54 %).
#                                             messy_url  \
# 0                      random text which is not a url
# 1   http://www.facebookee.com/otherpath?auth=faceb...
# 2   https://www.sfu.ca/ficticiouspath?auth=samplet...
# 3                                             notaurl
# 4                                                 NaN
# 5                                                None
# 6   https://www.sfu.ca/ficticiouspath?auth=samplet...
# 7
# 8                                 {'not_a_url': True}
# 9                                             2345678
# 10                                          345345345
# 11  https://www.sfu.ca/ficticiouspath?auth=samplet...
# 12  https://www.sfu.ca/ficticiouspath?auth=samplet...
#
#                                     messy_url_details
# 0                                                 NaN
# 1   {'scheme': 'http', 'host': 'www.facebookee.com...
# 2   {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 12  {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...

# %% [markdown]
# ### b. "ignore"
# This sets the value of invalid parsing as the input.

# %%
df_remove_errors_ignore = clean_url(df, column="messy_url", errors="ignore")
df_remove_errors_ignore
# Out:
# Url Cleaning report:
#         5 values parsed (38.46 %)
#         8 values unable to be parsed (61.54 %), set to their original values
# Result contains parsed key-value pairs for 5 (38.46 %) rows (stored in column `messy_url_details`) and 8 null / not parsable values(61.54 %).
#                                             messy_url  \
# 0                      random text which is not a url
# 1   http://www.facebookee.com/otherpath?auth=faceb...
# 2   https://www.sfu.ca/ficticiouspath?auth=samplet...
# 3                                             notaurl
# 4                                                 NaN
# 5                                                None
# 6   https://www.sfu.ca/ficticiouspath?auth=samplet...
# 7
# 8                                 {'not_a_url': True}
# 9                                             2345678
# 10                                          345345345
# 11  https://www.sfu.ca/ficticiouspath?auth=samplet...
# 12  https://www.sfu.ca/ficticiouspath?auth=samplet...
#
#                                     messy_url_details
# 0                      random text which is not a url
# 1   {'scheme': 'http', 'host': 'www.facebookee.com...
# 2   {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 3                                             notaurl
# 4                                                 NaN
# 5                                                None
# 6   {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 7
# 8                                 {'not_a_url': True}
# 9                                             2345678
# 10                                          345345345
# 11  {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 12  {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...

# %% [markdown]
# ### c. "raise"
# This will raise a value error when it encounters an invalid parsing value.

# %%
df_remove_errors_raise = clean_url(df, column="messy_url", errors="raise")
df_remove_errors_raise
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-fcf497836cf7> in <module>
# ----> 1 df_remove_errors_raise = clean_url(df, column="messy_url", errors="raise")
#       2 df_remove_errors_raise
#
# ~/dataprep/dataprep/clean/clean_url.py in clean_url(df, column, inplace, split, remove_auth, report, errors)
#     110     df = df.apply(format_url, args=(column, split, remove_auth, errors), axis=1, meta=meta)
#     111
# --> 112     df, nrows = dask.compute(df, df.shape[0])
#     113
#     114     if inplace:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     445         postcomputes.append(x.__dask_postcompute__())
#     446
# --> 447     results = schedule(dsk, keys, **kwargs)
#     448     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     449
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      82         get_id=_thread_get_id,
#      83         pack_exception=pack_exception,
# ---> 84         **kwargs
#      85     )
#      86
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dask/local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     484                         _execute_task(task, data)  # Re-execute locally
#     485                     else:
# --> 486                         raise_exception(exc, tb)
#     487                 res, worker_id = loads(res_info)
#     488                 state["cache"][key] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dask/local.py in reraise(exc, tb)
#     314     if exc.__traceback__ is not tb:
#     315         raise exc.with_traceback(tb)
# --> 316     raise exc
#     317
#     318
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     220     try:
#     221         task, data = loads(task_info)
# --> 222         result = _execute_task(task, data)
#     223         id = get_id()
#     224         result = dumps((result, id))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dask/optimization.py in __call__(self, *args)
#    1020         if not len(args) == len(self.inkeys):
#    1021             raise ValueError("Expected %d args, got %d" % (len(self.inkeys), len(args)))
# -> 1022         return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#    1023
#    1024     def __reduce__(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dask/core.py in get(dsk, out, cache)
#     149     for key in toposort(dsk):
#     150         task = dsk[key]
# --> 151         result = _execute_task(task, cache)
#     152         cache[key] = result
#     153     result = _execute_task(out, cache)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dask/utils.py in apply(func, args, kwargs)
#      29 def apply(func, args, kwargs=None):
#      30     if kwargs:
# ---> 31         return func(*args, **kwargs)
#      32     else:
#      33         return func(*args)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dask/dataframe/core.py in apply_and_enforce(*args, **kwargs)
#    5256     func = kwargs.pop("_func")
#    5257     meta = kwargs.pop("_meta")
# -> 5258     df = func(*args, **kwargs)
#    5259     if is_dataframe_like(df) or is_series_like(df) or is_index_like(df):
#    5260         if not len(df):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dask/utils.py in __call__(self, obj, *args, **kwargs)
#     893
#     894     def __call__(self, obj, *args, **kwargs):
# --> 895         return getattr(obj, self.method)(*args, **kwargs)
#     896
#     897     def __reduce__(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/apply.py in f(x)
#     111
#     112             def f(x):
# --> 113                 return func(x, *args, **kwds)
#     114
#     115         else:
#
# ~/dataprep/dataprep/clean/clean_url.py in format_url(row, column, split, remove_auth, errors)
#     133     else:
#     134         val_dict = get_url_params(
# --> 135             row[column], split=split, remove_auth=remove_auth, column=column, errors=errors
#     136         )
#     137         row[f"{column}_details"] = val_dict
#
# ~/dataprep/dataprep/clean/clean_url.py in get_url_params(url, column, split, remove_auth, errors)
#     152         else:
#     153             if errors == "raise":
# --> 154                 raise ValueError(f"Unable to parse value {url}")
#     155             return url if errors == "ignore" else np.nan
#     156
#
# ValueError: Unable to parse value random text which is not a url

# %% [markdown]
# ## 7. Report Parameter
# By default it is set to `True`, when set to `False` - will not display the stats pertaining to the cleaned operations performed.

# %%
df_remove_auth_boolean = clean_url(df, column="messy_url", remove_auth=True, report=False)
df_remove_auth_boolean
# Out:
#                                             messy_url  \
# 0                      random text which is not a url
# 1   http://www.facebookee.com/otherpath?auth=faceb...
# 2   https://www.sfu.ca/ficticiouspath?auth=samplet...
# 3                                             notaurl
# 4                                                 NaN
# 5                                                None
# 6   https://www.sfu.ca/ficticiouspath?auth=samplet...
# 7
# 8                                 {'not_a_url': True}
# 9                                             2345678
# 10                                          345345345
# 11  https://www.sfu.ca/ficticiouspath?auth=samplet...
# 12  https://www.sfu.ca/ficticiouspath?auth=samplet...
#
#                                     messy_url_details
# 0                                                 NaN
# 1   {'scheme': 'http', 'host': 'www.facebookee.com...
# 2   {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...
# 12  {'scheme': 'https', 'host': 'www.sfu.ca', 'mes...

# %% [markdown]
# ## 8. Validate_url
# validate_url() returns True when the input is a valid url. Otherwise it returns False.

# %%
from dataprep.clean import validate_url
print(validate_url({"not_a_url" : True}))
print(validate_url(2346789))
print(validate_url("https://www.sfu.ca/ficticiouspath?auth=sampletoken3&studentid=1231&loc=sur"))
print(validate_url("http://www.facebookee.com/otherpath?auth=facebookeeauth&token=iwusdkc&nottoken=hiThere&another_token=12323423"))
# Out:
# False
# False
# True
# True

# %%
df = pd.DataFrame({"messy_url":
                   ["random text which is not a url",
                    "http://www.facebookee.com/otherpath?auth=facebookeeauth&token=iwusdkc&nottoken=hiThere&another_token=12323423",
                    "https://www.sfu.ca/ficticiouspath?auth=sampletoken1&studentid=1234&loc=van", 
                    "notaurl", 
                    np.nan,
                    None, 
                    "https://www.sfu.ca/ficticiouspath?auth=sampletoken2&studentid=1230&loc=bur", 
                    "", 
                    {"not_a_url" : True}, 
                    "2345678", 
                    345345345,
                    "https://www.sfu.ca/ficticiouspath?auth=sampletoken3&studentid=1231&loc=sur",
                    "https://www.sfu.ca/ficticiouspath?auth=sampletoken1&studentid=1232&loc=van",
                    ]
                  })

df["validate_url"] = validate_url(df["messy_url"])
df
# Out:
#                                             messy_url  validate_url
# 0                      random text which is not a url         False
# 1   http://www.facebookee.com/otherpath?auth=faceb...          True
# 2   https://www.sfu.ca/ficticiouspath?auth=samplet...          True
# 3                                             notaurl         False
# 4                                                 NaN         False
# 5                                                None         False
# 6   https://www.sfu.ca/ficticiouspath?auth=samplet...          True
# 7                                                             False
# 8                                 {'not_a_url': True}         False
# 9                                             2345678         False
# 10                                          345345345         False
# 11  https://www.sfu.ca/ficticiouspath?auth=samplet...          True
# 12  https://www.sfu.ca/ficticiouspath?auth=samplet...          True
