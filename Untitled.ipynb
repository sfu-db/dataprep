# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from dataprep.eda.eda_plot_corr import plot_correlation
import pandas as pd, numpy as np

# %%
df = pd.DataFrame(np.random.rand(1000,5))
df.columns = list("abcde")

# %%
plot_correlation(df, x_name="a", y_name="b")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-a97e39f61f0b> in <module>
# ----> 1 plot_correlation(df, x_name="a", y_name="b")
#
# ~/dataprep/dataprep/eda/eda_plot_corr.py in plot_correlation(pd_data_frame, x_name, y_name, k, method, return_intermediate)
#     674             if k != 0:
#     675                 fig = _vis_correlation_pd_x_y_k(
# --> 676                     intermediate=intermediate
#     677                 )
#     678             else:
#
# ~/dataprep/dataprep/eda/eda_plot_corr.py in _vis_correlation_pd_x_y_k(intermediate)
#     234     )
#     235     fig.circle(
# --> 236         result['dec_point_x'],
#     237         result['dec_point_y'],
#     238         legend='decrease points',
#
# KeyError: 'dec_point_x'
